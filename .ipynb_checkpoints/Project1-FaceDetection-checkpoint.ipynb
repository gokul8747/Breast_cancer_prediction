# %% [markdown]
# # ACMEGRADE MACHINE LEARNING

# %% [markdown]
# ## BATCH START: AUGUST

# %% [markdown]
# ### NAME:M.BHARATH

# %% [markdown]
# ### PROJECT: FACE DETECTION USING OPEN-CV

# %% [markdown]
# #### importing libraries

# %%
import matplotlib.pyplot as plt
import cv as cv

# %% [markdown]
# #### import dataset for face detection

# %%
face_detector = cv.CascadeClassifier('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\haarcascade_frontalface_default.xml')

# %%
image = cv.imread('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Data Set\\people1.jpg')
image = cv.resize(image, (800, 600)) 
detections = face_detector.detectMultiScale(image)

# %%
print('Original Image')
plt.imshow(image)
plt.show()
# Out:
# Original Image

# %%
image = cv.resize(image, (800, 600)) 
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)

# %%
faces = detections
for (x,y,w,h) in faces:
    cv.rectangle(image,(x,y),(x+y,y+h),(255,0,0),2)
plt.imshow(image)
plt.show()

# %% [markdown]
# #### face detection over live video

# %%
cap = cv.VideoCapture(0)
cap.set(3,640) # set Width
cap.set(4,480) # set Height

while True:
    ret, img = cap.read()
    img = cv.flip(img, 1)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(
        gray,
        
        scaleFactor=1.2,
        minNeighbors=5
        ,     
        minSize=(20, 20)
    )

    for (x,y,w,h) in faces:
        cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        

    cv.imshow('video',img)

    k = cv.waitKey(30) & 0xff
    if k == 27: # press esc to exit
        break

cap.release()
cv.destroyAllWindows()

# %% [markdown]
# ### EYE detetction over image

# %%
eye_detector= cv.CascadeClassifier('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Cascades\\haarcascade_eye.xml')

# %%
eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

# %%
for (x, y, w, h) in eye_detections:
  cv.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
plt.imshow(image)
plt.show()

# %% [markdown]
# #### eye detetctor over live video

# %%
cap = cv.VideoCapture(0)
cap.set(3,640) 
cap.set(4,480) 

while True:
    ret, img = cap.read()
    img = cv.flip(img, 1)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    eyes = eye_detector.detectMultiScale(
        gray,
        
        scaleFactor=1.2,
        minNeighbors=5
        ,     
        minSize=(20, 20)
    )

    for (x,y,w,h) in eyes:
        cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        

    cv.imshow('video',img)

    k = cv.waitKey(30) & 0xff
    if k == 27: # press esc to exit
        break

cap.release()
cv.destroyAllWindows()

# %% [markdown]
# #### car detetction

# %%
car_detector = cv.CascadeClassifier('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Cascades\\cars.xml')

# %%
image = cv.imread('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Data Set\\car.jpg')

# %%
detections = car_detector.detectMultiScale(image, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
    
plt.imshow(image)
plt.show()

# %% [markdown]
# #### clock detection

# %%
clock_detector = cv.CascadeClassifier('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Cascades\\clocks.xml')

# %%
image = cv.imread('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Data Set\\clock.jpg')

# %%
detections = clock_detector.detectMultiScale(image, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()

# %% [markdown]
# #### full detecter

# %%
full_detector  = cv.CascadeClassifier('C:\\Users\\sivasankar\\Desktop\\ML\\Projects\\PRJ Face Detection\\Cascades\\fullbody.xml')

# %%
image = cv.imread('C:\\Users\\sivasankar\\Desktop\\\\ML\\Projects\\PRJ Face Detection\\Data Set\\people3.jpg')

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,
                                              minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()
